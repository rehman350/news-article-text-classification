# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load dataset from Data folder
# -------------------------------
df = pd.read_csv("Data/sample_training_data.csv")

df.head()
# Out:
#                                                 text  label
# 0  Wall St. Bears Claw Back Into the Black (Reute...      2
# 1  Carlyle Looks Toward Commercial Aerospace (Reu...      2
# 2  Oil and Economy Cloud Stocks' Outlook (Reuters...      2
# 3  Iraq Halts Oil Exports from Main Southern Pipe...      2
# 4  Oil prices soar to all-time record, posing new...      2

# %%
print("Dataset Info\n")
df.info()

print("\nStatistics Info\n")
df.describe()
# Out:
# Dataset Info
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    100 non-null    object
#  1   label   100 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 1.7+ KB
#
# Statistics Info
#             label
# count  100.000000
# mean     2.220000
# std      0.416333
# min      2.000000
# 25%      2.000000
# 50%      2.000000
# 75%      2.000000
# max      3.000000

# %%
# Check label distribution

df['label'].value_counts()
# Out:
# label
# 2    78
# 3    22
# Name: count, dtype: int64

# %%
# Create word count column for analysis
# -------------------------------
df['word_count'] = df['text'].apply(lambda x: len(str(x).split()))
df[['label','word_count']].head()
# Out:
#    label  word_count
# 0      2          21
# 1      2          36
# 2      2          36
# 3      2          36
# 4      2          37

# %%
# Plot word count distribution
# -------------------------------
sns.histplot(df['word_count'], kde=True)
plt.title("Word Count Distribution")
plt.show()

# %%
# Boxplot by label
# -------------------------------
sns.boxplot(x=df['label'], y=df['word_count'])
plt.title("Word Count by Label")
plt.show()

# %% [markdown]
# Now check Explore the data after perform the preprocessing

# %%
df = pd.read_csv("Data/clean_data.csv")

df['word_count'] = df['clean_text'].apply(lambda x: len(str(x).split()))

# %%
sns.histplot(df['word_count'], kde=True)
plt.title("Word Count Distribution (After Preprocessing)")
plt.show()

# %%
sns.boxplot(x=df['label'], y=df['word_count'])
plt.title("Word Count by Label (After Preprocessing)")
plt.show()
